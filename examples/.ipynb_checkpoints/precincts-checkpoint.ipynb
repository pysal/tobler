# %% [markdown]
# # Areal interpolation: Tracts to Voting Precincts
#
# This notebook demonstrates the interpolation of an intensive variable (Pct Youth) measured for the census tracts tracts in Riverside and San Bernardino counties in California to the voting precincts in the respective counties.

# %%
import tobler
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import geopandas

# %%
# !ls *.zip
# Out:
# riverside_precinct.zip	sb_precinct.zip  tract.zip

# %%
tracts = geopandas.read_file("zip:tract.zip")

# %%
tracts.plot()

# %%
sb_precinct = geopandas.read_file("zip:sb_precinct.zip")

# %%
sb_precinct.plot()

# %%
riverside_precinct = geopandas.read_file("zip:riverside_precinct.zip")

# %%
riverside_precinct.plot()

# %% [markdown]
# ## Check the coordinate reference systems

# %%
riverside_precinct.crs
# Out:
# {'init': 'epsg:2230'}

# %%
tracts.crs
# Out:
# {'init': 'epsg:4326'}

# %%
sb_precinct.crs == tracts.crs
# Out:
# False

# %%
sb_precinct.crs
# Out:
# {'init': 'epsg:2229'}

# %%
sb_precinct.crs == riverside_precinct.crs
# Out:
# False

# %% [markdown]
# ## Combine the precincts

# %%
#pd.concat([gdf1, gdf2])
import pandas
precincts = pandas.concat([riverside_precinct, sb_precinct], ignore_index=True)
# Out:
# /home/serge/anaconda3/envs/tobler/lib/python3.7/site-packages/ipykernel_launcher.py:3: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
type(precincts)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
precincts.plot() # different crs' in the two DataFrames

# %% [markdown]
# Note the error due to the different crs in the two precinct files.
#
# Set the crs to be the same in each dataframe:

# %%
riverside_precinct = tracts.to_crs(sb_precinct.crs)
precincts = pandas.concat([riverside_precinct, sb_precinct], ignore_index=False)
precincts.plot()
# Out:
# /home/serge/anaconda3/envs/tobler/lib/python3.7/site-packages/ipykernel_launcher.py:2: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.

# %%
precincts.crs
# Out:
# {'init': 'epsg:2229'}

# %% [markdown]
# ## Area interpolation I

# %%
area_table = tobler.area_tables(tracts, precincts)
# Out:
# Source and target dataframes have different crs. Please correct.

# %% [markdown]
# tobler flags the problem, and warns the user to set the correct crs on the source and target dataframes.

# %%
tracts = tracts.to_crs(precincts.crs)

# %%
area_table = tobler.area_tables(tracts, precincts) # this will throw and error in geopandas
# Out:
# TopologyException: found non-noded intersection between LINESTRING (6.91831e+06 1.92428e+06, 6.91831e+06 1.92428e+06) and LINESTRING (6.91831e+06 1.92428e+06, 6.91831e+06 1.92428e+06) at 6918306.5279321205 1924277.5882309526
# ---------------------------------------------------------------------------
# TopologicalError                          Traceback (most recent call last)
# <ipython-input-97-eb8d10d4d6a9> in <module>
# ----> 1 area_table = tobler.area_tables(tracts, precincts) # this will throw and error in geopandas
#
# ~/Dropbox/t/tobler/tobler/area_weighted.py in area_tables(source_df, target_df)
#      50     source_df.loc[:, '_left'] = _left  # create temporary index for union
#      51     target_df.loc[:, '_right'] = _right # create temporary index for union
# ---> 52     res_union = gpd.overlay(source_df, target_df, how='union')
#      53     n_u, _ = res_union.shape
#      54     SU = np.zeros((n_s, n_u)) # holds area of intersection of source geom with union geom
#
# ~/anaconda3/envs/tobler/lib/python3.7/site-packages/geopandas/tools/overlay.py in overlay(df1, df2, how, make_valid, use_sindex)
#     369         result = _overlay_symmetric_diff(df1, df2)
#     370     elif how == 'union':
# --> 371         result = _overlay_union(df1, df2)
#     372     elif how == 'identity':
#     373         dfunion = _overlay_union(df1, df2)
#
# ~/anaconda3/envs/tobler/lib/python3.7/site-packages/geopandas/tools/overlay.py in _overlay_union(df1, df2)
#     297     """
#     298     dfinter = _overlay_intersection(df1, df2)
# --> 299     dfsym = _overlay_symmetric_diff(df1, df2)
#     300     dfunion = pd.concat([dfinter, dfsym], ignore_index=True, **CONCAT_KWARGS)
#     301     # keep geometry column last
#
# ~/anaconda3/envs/tobler/lib/python3.7/site-packages/geopandas/tools/overlay.py in _overlay_symmetric_diff(df1, df2)
#     271     Overlay Symmetric Difference operation used in overlay function
#     272     """
# --> 273     dfdiff1 = _overlay_difference(df1, df2)
#     274     dfdiff2 = _overlay_difference(df2, df1)
#     275     dfdiff1['__idx1'] = range(len(dfdiff1))
#
# ~/anaconda3/envs/tobler/lib/python3.7/site-packages/geopandas/tools/overlay.py in _overlay_difference(df1, df2)
#     258     for geom, neighbours in zip(df1.geometry, sidx):
#     259         new = reduce(lambda x, y: x.difference(y).buffer(0),
# --> 260                      [geom] + list(df2.geometry.iloc[neighbours]))
#     261         new_g.append(new)
#     262     differences = GeoSeries(new_g, index=df1.index)
#
# ~/anaconda3/envs/tobler/lib/python3.7/site-packages/geopandas/tools/overlay.py in <lambda>(x, y)
#     257     new_g = []
#     258     for geom, neighbours in zip(df1.geometry, sidx):
# --> 259         new = reduce(lambda x, y: x.difference(y).buffer(0),
#     260                      [geom] + list(df2.geometry.iloc[neighbours]))
#     261         new_g.append(new)
#
# ~/anaconda3/envs/tobler/lib/python3.7/site-packages/shapely/geometry/base.py in difference(self, other)
#     614     def difference(self, other):
#     615         """Returns the difference of the geometries"""
# --> 616         return geom_factory(self.impl['difference'](self, other))
#     617
#     618     def intersection(self, other):
#
# ~/anaconda3/envs/tobler/lib/python3.7/site-packages/shapely/topology.py in __call__(self, this, other, *args)
#      68             err = TopologicalError(
#      69                     "This operation could not be performed. Reason: unknown")
# ---> 70             self._check_topology(err, this, other)
#      71         return product
#      72
#
# ~/anaconda3/envs/tobler/lib/python3.7/site-packages/shapely/topology.py in _check_topology(self, err, *geoms)
#      37                     "Likely cause is invalidity of the geometry %s" % (
#      38                         self.fn.__name__, repr(geom)))
# ---> 39         raise err
#      40
#      41
#
# TopologicalError: This operation could not be performed. Reason: unknown

# %% [markdown]
# It appears that the concatenate operation in geopandas results in a dataframe with problematic geometries.
#
# We can turn to qgis to do the merge of the two precinct files to get around this.

# %% [markdown]
# ## Area interpolation II

# %%
precincts = geopandas.read_file('precincts.shp') # precincts.shp was created in qgis merginging the 2 precinct shapefiles

# %%
tracts = tracts.to_crs(precincts.crs)

# %%
area_table = tobler.area_tables(tracts, precincts)

# %%
estimates = tobler.area_interpolate(tracts, precincts, intensive_variables=['pct Youth'], tables=area_table)
# Out:
# nan values in variable: pct Youth, replacing with 0.0

# %%
estimates # we only have intensive variables so the first element will be empty
# Out:
# (array([], dtype=float64),
#  array([[0.42896822, 0.23996352, 0.70018819, ..., 0.18013978, 0.11000376,
#          0.22      ]]))

# %%
pct_youth = estimates[-1]
pct_youth.shape = (-1, 1)
precincts['pct Youth'] = pct_youth

# %%
precincts.columns
# Out:
# Index(['fid', 'sVotingPre', 'SUM_lTotal', 'VPMapping', 'PRECINCTID',
#        'PRECINCT_N', 'PRCNCT_PRT', 'ABRV_NAME', 'layer', 'path', 'geometry',
#        'pct Youth'],
#       dtype='object')

# %%
f, ax = plt.subplots(1, figsize=(8, 8))
ax = precincts.plot(column='pct Youth', ax=ax, legend=True, alpha=0.5, scheme='Quantiles', k=9)
plt.show()

# %%
f, ax = plt.subplots(1, figsize=(8, 8))
ax = tracts.plot(column='pct Youth',ax=ax)
plt.show() # will throw and error since there are NANs in the pct Youth column
# Out:
# /home/serge/anaconda3/envs/tobler/lib/python3.7/site-packages/matplotlib/colors.py:512: RuntimeWarning: invalid value encountered in less
#   xa[xa < 0] = -1

# %%
f, ax = plt.subplots(1, figsize=(8, 8))
ax = precincts.plot(column='pct Youth', ax=ax, legend=True, alpha=0.5, scheme='fisher_jenks', k=9)
plt.show()

# %%
tract_old = tracts[['pct Youth']].values.copy()

# %%
np.where(np.isnan(tract_old))
# Out:
# (array([ 91, 497]), array([0, 0]))

# %%
tracts.iloc[[91, 497], :]
# Out:
#     STATEFP COUNTYFP TRACTCE        GEOID  \
# 91       06      071  980100  06071980100
# 497      06      065  980004  06065980004
#
#                                                IE_NAME  IE_pct_you  pct Youth  \
# 91   Census Tract 9801, San Bernardino County, Cali...         NaN        NaN
# 497  Census Tract 9800.04, Riverside County, Califo...         NaN        NaN
#
#                                               geometry
# 91   POLYGON ((6253583.060836275 2344277.513052656,...
# 497  POLYGON ((6233691.07248152 2285767.348271345, ...

# %%
# replace nans in tract data
tract_pct_youth = tracts[['pct Youth']].values
import numpy as np
wherenan = np.isnan(tract_pct_youth)
tract_pct_youth[wherenan] = 0.0
tracts['pct Youth'] = tract_pct_youth

# %%
f, ax = plt.subplots(1, figsize=(8, 8))
ax = tracts.plot(column='pct Youth', ax=ax, legend=True, alpha=0.5, scheme='fisher_jenks', k=9)
plt.show()

# %%
precincts.to_file('precincts_interpolated.shp')
